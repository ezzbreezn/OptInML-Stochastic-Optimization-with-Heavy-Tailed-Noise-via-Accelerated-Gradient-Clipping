# %%
import numpy as np
from numpy.linalg import norm
import pickle
import matplotlib
import matplotlib.pyplot as plt
import itertools
from scipy.stats import norm as norm_d
from scipy.stats import expon
from scipy.stats import weibull_min as weibull
from scipy.stats import burr12 as burr
from scipy.stats import randint
from scipy.stats import uniform
from scipy.optimize import minimize
import copy
import math
import time
from scipy.optimize import minimize
from scipy.sparse.linalg import svds
from scipy.linalg import svdvals
import scipy
from sklearn.datasets import load_svmlight_file
import pickle
from pathlib import Path
from functions import *
from algorithms import *
from utils import *
from tests import *

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %matplotlib inline

# %% [markdown]
# # Logistic regression

# %% [markdown]
# ## w8a

# %%
# %%time
dataset = "w8a"
A, y, m, n, sparsity_A = prepare_data(dataset)
print("Number of functions: ", m, ", dimension: ", n)
L, average_L, worst_L = compute_L(dataset, A)
denseA = A.toarray()
print("Smoothness const: ", L)
print("Average smoothness const: ", average_L)
print("Worst smoothness const: ", worst_L)
print("Percentage of non-zeros: ", sparsity_A)
# Out:
# Number of functions:  49749 , dimension:  300
# Smoothness const:  0.6611993844944797
# Average smoothness const:  2.912551006050437
# Worst smoothness const:  28.5
# Percentage of non-zeros:  0.03883401341400497
# CPU times: user 1.66 s, sys: 388 ms, total: 2.04 s
# Wall time: 2.22 s

# %% [markdown]
# ### Find the solution (Run this part only once)

# %%
filename=dataset+"_x_init_all_ones"
x_init = np.ones(n)
l2 = 0
l1 = 0

# %%
# %%time
param = [A, y, l2, False, l1]
res_solver = minimize(F, x_init, args = param, jac=logreg_grad_plus_lasso, 
                      method='L-BFGS-B',
                      options={'maxiter':10000, 'disp':True}, tol=1e-18)

print(res_solver.success)
print(res_solver.fun)
print(res_solver)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          300     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.14583D+01    |proj g|=  3.41627D-01
#
# At iterate    1    f=  6.90811D-01    |proj g|=  4.67196D-02
#
# At iterate    2    f=  2.76344D-01    |proj g|=  7.44703D-03
#
# At iterate    3    f=  2.59001D-01    |proj g|=  5.11335D-03
#
# At iterate    4    f=  2.38580D-01    |proj g|=  4.86430D-03
#
# At iterate    5    f=  1.85569D-01    |proj g|=  4.03542D-03
#
# At iterate    6    f=  1.57455D-01    |proj g|=  5.73893D-03
#
# At iterate    7    f=  1.45127D-01    |proj g|=  1.52558D-03
#
# At iterate    8    f=  1.40031D-01    |proj g|=  1.92909D-03
#
# At iterate    9    f=  1.29634D-01    |proj g|=  1.96510D-03
#  This problem is unconstrained.
# At iterate   10    f=  1.28424D-01    |proj g|=  1.93445D-03
#
# At iterate   11    f=  1.27147D-01    |proj g|=  2.22483D-03
#
# At iterate   12    f=  1.24750D-01    |proj g|=  4.48810D-04
#
# At iterate   13    f=  1.24065D-01    |proj g|=  3.34608D-04
#
# At iterate   14    f=  1.22629D-01    |proj g|=  4.85031D-04
#
# At iterate   15    f=  1.20525D-01    |proj g|=  4.20090D-04
#
# At iterate   16    f=  1.19561D-01    |proj g|=  1.27161D-03
#
# At iterate   17    f=  1.17671D-01    |proj g|=  3.10032D-04
#
# At iterate   18    f=  1.17236D-01    |proj g|=  2.10177D-04
#
# At iterate   19    f=  1.16653D-01    |proj g|=  2.71142D-04
#
# At iterate   20    f=  1.15956D-01    |proj g|=  3.55436D-04
#
# At iterate   21    f=  1.14785D-01    |proj g|=  4.12075D-04
#
# At iterate   22    f=  1.14296D-01    |proj g|=  5.71098D-04
#
# At iterate   23    f=  1.13827D-01    |proj g|=  1.42026D-04
#
# At iterate   24    f=  1.13617D-01    |proj g|=  2.21446D-04
#
# At iterate   25    f=  1.13364D-01    |proj g|=  1.97199D-04
#
# At iterate   26    f=  1.13229D-01    |proj g|=  4.78007D-04
#
# At iterate   27    f=  1.12981D-01    |proj g|=  2.15885D-04
#
# At iterate   28    f=  1.12829D-01    |proj g|=  1.07490D-04
#
# At iterate   29    f=  1.12703D-01    |proj g|=  1.39862D-04
#
# At iterate   30    f=  1.12561D-01    |proj g|=  9.77840D-05
#
# At iterate   31    f=  1.12356D-01    |proj g|=  1.44395D-04
#
# At iterate   32    f=  1.12177D-01    |proj g|=  1.37049D-04
#
# At iterate   33    f=  1.12037D-01    |proj g|=  1.25037D-04
#
# At iterate   34    f=  1.11802D-01    |proj g|=  9.43021D-05
#
# At iterate   35    f=  1.11691D-01    |proj g|=  7.97327D-05
#
# At iterate   36    f=  1.11618D-01    |proj g|=  6.02333D-05
#
# At iterate   37    f=  1.11491D-01    |proj g|=  7.38356D-05
#
# At iterate   38    f=  1.11462D-01    |proj g|=  1.50757D-04
#
# At iterate   39    f=  1.11424D-01    |proj g|=  7.61946D-05
#
# At iterate   40    f=  1.11390D-01    |proj g|=  3.93639D-05
#
# At iterate   41    f=  1.11363D-01    |proj g|=  5.36194D-05
#
# At iterate   42    f=  1.11315D-01    |proj g|=  7.45124D-05
#
# At iterate   43    f=  1.11291D-01    |proj g|=  7.55501D-05
#
# At iterate   44    f=  1.11260D-01    |proj g|=  3.71830D-05
#
# At iterate   45    f=  1.11246D-01    |proj g|=  2.95267D-05
#
# At iterate   46    f=  1.11230D-01    |proj g|=  3.49562D-05
#
# At iterate   47    f=  1.11192D-01    |proj g|=  6.23409D-05
#
# At iterate   48    f=  1.11173D-01    |proj g|=  4.90708D-05
#
# At iterate   49    f=  1.11156D-01    |proj g|=  4.03679D-05
#
# At iterate   50    f=  1.11146D-01    |proj g|=  7.87133D-05
#
# At iterate   51    f=  1.11131D-01    |proj g|=  3.99501D-05
#
# At iterate   52    f=  1.11113D-01    |proj g|=  3.77051D-05
#
# At iterate   53    f=  1.11092D-01    |proj g|=  3.75795D-05
#
# At iterate   54    f=  1.11078D-01    |proj g|=  5.21139D-05
#
# At iterate   55    f=  1.11064D-01    |proj g|=  2.94044D-05
#
# At iterate   56    f=  1.11052D-01    |proj g|=  2.38117D-05
#
# At iterate   57    f=  1.11037D-01    |proj g|=  2.56106D-05
#
# At iterate   58    f=  1.11028D-01    |proj g|=  5.51563D-05
#
# At iterate   59    f=  1.11018D-01    |proj g|=  5.39572D-05
#
# At iterate   60    f=  1.11013D-01    |proj g|=  1.68109D-05
#
# At iterate   61    f=  1.11009D-01    |proj g|=  2.21399D-05
#
# At iterate   62    f=  1.11003D-01    |proj g|=  4.47716D-05
#
# At iterate   63    f=  1.10994D-01    |proj g|=  3.43074D-05
#
# At iterate   64    f=  1.10990D-01    |proj g|=  8.83599D-05
#
# At iterate   65    f=  1.10982D-01    |proj g|=  3.17963D-05
#
# At iterate   66    f=  1.10974D-01    |proj g|=  2.01556D-05
#
# At iterate   67    f=  1.10966D-01    |proj g|=  3.93206D-05
#
# At iterate   68    f=  1.10958D-01    |proj g|=  3.53962D-05
#
# At iterate   69    f=  1.10953D-01    |proj g|=  3.75357D-05
#
# At iterate   70    f=  1.10946D-01    |proj g|=  2.20870D-05
#
# At iterate   71    f=  1.10941D-01    |proj g|=  2.59803D-05
#
# At iterate   72    f=  1.10935D-01    |proj g|=  2.76463D-05
#
# At iterate   73    f=  1.10928D-01    |proj g|=  2.49995D-05
#
# At iterate   74    f=  1.10926D-01    |proj g|=  5.65683D-05
#
# At iterate   75    f=  1.10918D-01    |proj g|=  1.52433D-05
#
# At iterate   76    f=  1.10916D-01    |proj g|=  1.32910D-05
#
# At iterate   77    f=  1.10912D-01    |proj g|=  3.66187D-05
#
# At iterate   78    f=  1.10908D-01    |proj g|=  4.23851D-05
#
# At iterate   79    f=  1.10905D-01    |proj g|=  1.49744D-05
#
# At iterate   80    f=  1.10900D-01    |proj g|=  1.65558D-05
#
# At iterate   81    f=  1.10897D-01    |proj g|=  2.39918D-05
#
# At iterate   82    f=  1.10895D-01    |proj g|=  2.21248D-05
#
# At iterate   83    f=  1.10890D-01    |proj g|=  1.20021D-05
#
# At iterate   84    f=  1.10888D-01    |proj g|=  8.38706D-06
#
# At iterate   85    f=  1.10886D-01    |proj g|=  1.11740D-05
#
# At iterate   86    f=  1.10883D-01    |proj g|=  1.27026D-05
#
# At iterate   87    f=  1.10878D-01    |proj g|=  1.29402D-05
#
# At iterate   88    f=  1.10877D-01    |proj g|=  1.55465D-05
#
# At iterate   89    f=  1.10875D-01    |proj g|=  7.34295D-06
#
# At iterate   90    f=  1.10874D-01    |proj g|=  8.56595D-06
#
# At iterate   91    f=  1.10873D-01    |proj g|=  2.71187D-05
#
# At iterate   92    f=  1.10872D-01    |proj g|=  1.67716D-05
#
# At iterate   93    f=  1.10870D-01    |proj g|=  8.30720D-06
#
# At iterate   94    f=  1.10869D-01    |proj g|=  2.21614D-05
#
# At iterate   95    f=  1.10868D-01    |proj g|=  1.03699D-05
#
# At iterate   96    f=  1.10867D-01    |proj g|=  8.09252D-06
#
# At iterate   97    f=  1.10865D-01    |proj g|=  1.19377D-05
#
# At iterate   98    f=  1.10863D-01    |proj g|=  1.06387D-05
#
# At iterate   99    f=  1.10860D-01    |proj g|=  2.98546D-05
#
# At iterate  100    f=  1.10859D-01    |proj g|=  3.45859D-05
#
# At iterate  101    f=  1.10858D-01    |proj g|=  1.38150D-05
#
# At iterate  102    f=  1.10857D-01    |proj g|=  1.70851D-05
#
# At iterate  103    f=  1.10856D-01    |proj g|=  8.24165D-06
#
# At iterate  104    f=  1.10855D-01    |proj g|=  7.94537D-06
#
# At iterate  105    f=  1.10854D-01    |proj g|=  3.87393D-05
#
# At iterate  106    f=  1.10853D-01    |proj g|=  1.84639D-05
#
# At iterate  107    f=  1.10853D-01    |proj g|=  5.80494D-06
#
# At iterate  108    f=  1.10852D-01    |proj g|=  7.29426D-06
#
# At iterate  109    f=  1.10851D-01    |proj g|=  1.27459D-05
#
# At iterate  110    f=  1.10850D-01    |proj g|=  8.29209D-06
#
# At iterate  111    f=  1.10849D-01    |proj g|=  5.26190D-06
#
# At iterate  112    f=  1.10847D-01    |proj g|=  6.41404D-06
#
# At iterate  113    f=  1.10847D-01    |proj g|=  3.02599D-05
#
# At iterate  114    f=  1.10846D-01    |proj g|=  1.60099D-05
#
# At iterate  115    f=  1.10845D-01    |proj g|=  1.37945D-05
#
# At iterate  116    f=  1.10844D-01    |proj g|=  4.64123D-06
#
# At iterate  117    f=  1.10844D-01    |proj g|=  1.06489D-05
#
# At iterate  118    f=  1.10843D-01    |proj g|=  4.05333D-05
#
# At iterate  119    f=  1.10842D-01    |proj g|=  1.11429D-05
#
# At iterate  120    f=  1.10841D-01    |proj g|=  4.07311D-06
#
# At iterate  121    f=  1.10841D-01    |proj g|=  8.49287D-06
#
# At iterate  122    f=  1.10840D-01    |proj g|=  3.30250D-05
#
# At iterate  123    f=  1.10839D-01    |proj g|=  1.24636D-05
#
# At iterate  124    f=  1.10839D-01    |proj g|=  4.84425D-06
#
# At iterate  125    f=  1.10838D-01    |proj g|=  8.48087D-06
#
# At iterate  126    f=  1.10837D-01    |proj g|=  1.89280D-05
#
# At iterate  127    f=  1.10837D-01    |proj g|=  1.16748D-05
#
# At iterate  128    f=  1.10836D-01    |proj g|=  3.70658D-06
#
# At iterate  129    f=  1.10836D-01    |proj g|=  5.24557D-06
#
# At iterate  130    f=  1.10836D-01    |proj g|=  5.29649D-06
#
# At iterate  131    f=  1.10835D-01    |proj g|=  2.29085D-05
#
# At iterate  132    f=  1.10834D-01    |proj g|=  3.53236D-06
#
# At iterate  133    f=  1.10834D-01    |proj g|=  3.40824D-06
#
# At iterate  134    f=  1.10834D-01    |proj g|=  5.76134D-06
#
# At iterate  135    f=  1.10833D-01    |proj g|=  1.05043D-05
#
# At iterate  136    f=  1.10832D-01    |proj g|=  7.31765D-06
#
# At iterate  137    f=  1.10832D-01    |proj g|=  8.93346D-06
#
# At iterate  138    f=  1.10831D-01    |proj g|=  6.08576D-06
#
# At iterate  139    f=  1.10831D-01    |proj g|=  5.12033D-06
#
# At iterate  140    f=  1.10831D-01    |proj g|=  6.02490D-06
#
# At iterate  141    f=  1.10830D-01    |proj g|=  5.30839D-06
#
# At iterate  142    f=  1.10830D-01    |proj g|=  7.26856D-06
#
# At iterate  143    f=  1.10830D-01    |proj g|=  1.50722D-05
#
# At iterate  144    f=  1.10829D-01    |proj g|=  6.91028D-06
#
# At iterate  145    f=  1.10829D-01    |proj g|=  3.87062D-06
#
# At iterate  146    f=  1.10828D-01    |proj g|=  5.67000D-06
#
# At iterate  147    f=  1.10827D-01    |proj g|=  6.55240D-06
#
# At iterate  148    f=  1.10827D-01    |proj g|=  1.54073D-05
#
# At iterate  149    f=  1.10827D-01    |proj g|=  5.99075D-06
#
# At iterate  150    f=  1.10826D-01    |proj g|=  1.07905D-05
#
# At iterate  151    f=  1.10826D-01    |proj g|=  5.29235D-06
#
# At iterate  152    f=  1.10826D-01    |proj g|=  6.45795D-06
#
# At iterate  153    f=  1.10826D-01    |proj g|=  6.71906D-06
#
# At iterate  154    f=  1.10826D-01    |proj g|=  9.11933D-06
#
# At iterate  155    f=  1.10825D-01    |proj g|=  8.18743D-06
#
# At iterate  156    f=  1.10825D-01    |proj g|=  1.93050D-05
#
# At iterate  157    f=  1.10824D-01    |proj g|=  4.26279D-06
#
# At iterate  158    f=  1.10824D-01    |proj g|=  5.21694D-06
#
# At iterate  159    f=  1.10824D-01    |proj g|=  8.39010D-06
#
# At iterate  160    f=  1.10824D-01    |proj g|=  2.41448D-05
#
# At iterate  161    f=  1.10823D-01    |proj g|=  8.28943D-06
#
# At iterate  162    f=  1.10823D-01    |proj g|=  2.40953D-06
#
# At iterate  163    f=  1.10823D-01    |proj g|=  4.87135D-06
#
# At iterate  164    f=  1.10823D-01    |proj g|=  1.00052D-05
#
# At iterate  165    f=  1.10823D-01    |proj g|=  3.70432D-06
#
# At iterate  166    f=  1.10823D-01    |proj g|=  4.70108D-06
#
# At iterate  167    f=  1.10822D-01    |proj g|=  5.03534D-06
#
# At iterate  168    f=  1.10822D-01    |proj g|=  5.48299D-06
#
# At iterate  169    f=  1.10822D-01    |proj g|=  3.06751D-05
#
# At iterate  170    f=  1.10821D-01    |proj g|=  2.88862D-06
#
# At iterate  171    f=  1.10821D-01    |proj g|=  3.11113D-06
#
# At iterate  172    f=  1.10821D-01    |proj g|=  6.79849D-06
#
# At iterate  173    f=  1.10821D-01    |proj g|=  6.97416D-06
#
# At iterate  174    f=  1.10821D-01    |proj g|=  7.51698D-06
#
# At iterate  175    f=  1.10821D-01    |proj g|=  2.26018D-06
#
# At iterate  176    f=  1.10820D-01    |proj g|=  3.50224D-06
#
# At iterate  177    f=  1.10820D-01    |proj g|=  3.89381D-06
#
# At iterate  178    f=  1.10820D-01    |proj g|=  1.54012D-05
#
# At iterate  179    f=  1.10820D-01    |proj g|=  3.63696D-06
#
# At iterate  180    f=  1.10820D-01    |proj g|=  3.15011D-06
#
# At iterate  181    f=  1.10820D-01    |proj g|=  3.34213D-06
#
# At iterate  182    f=  1.10820D-01    |proj g|=  7.48741D-06
#
# At iterate  183    f=  1.10819D-01    |proj g|=  8.15844D-06
#
# At iterate  184    f=  1.10819D-01    |proj g|=  4.56066D-06
#
# At iterate  185    f=  1.10819D-01    |proj g|=  2.31188D-06
#
# At iterate  186    f=  1.10819D-01    |proj g|=  2.47194D-06
#
# At iterate  187    f=  1.10818D-01    |proj g|=  1.24945D-05
#
# At iterate  188    f=  1.10818D-01    |proj g|=  4.50873D-06
#
# At iterate  189    f=  1.10818D-01    |proj g|=  2.26195D-06
#
# At iterate  190    f=  1.10818D-01    |proj g|=  3.03117D-06
#
# At iterate  191    f=  1.10818D-01    |proj g|=  6.25022D-06
#
# At iterate  192    f=  1.10818D-01    |proj g|=  3.20591D-06
#
# At iterate  193    f=  1.10817D-01    |proj g|=  3.79635D-06
#
# At iterate  194    f=  1.10817D-01    |proj g|=  3.27324D-06
#
# At iterate  195    f=  1.10817D-01    |proj g|=  2.62031D-06
#
# At iterate  196    f=  1.10817D-01    |proj g|=  9.86422D-06
#
# At iterate  197    f=  1.10817D-01    |proj g|=  6.02678D-06
#
# At iterate  198    f=  1.10817D-01    |proj g|=  2.62790D-06
#
# At iterate  199    f=  1.10817D-01    |proj g|=  2.74510D-06
#
# At iterate  200    f=  1.10816D-01    |proj g|=  2.65193D-06
#
# At iterate  201    f=  1.10816D-01    |proj g|=  6.20823D-06
#
# At iterate  202    f=  1.10816D-01    |proj g|=  4.17617D-06
#
# At iterate  203    f=  1.10816D-01    |proj g|=  2.05501D-06
#
# At iterate  204    f=  1.10816D-01    |proj g|=  4.26564D-06
#
# At iterate  205    f=  1.10816D-01    |proj g|=  2.64961D-06
#
# At iterate  206    f=  1.10816D-01    |proj g|=  3.86997D-06
#
# At iterate  207    f=  1.10816D-01    |proj g|=  3.39358D-06
#
# At iterate  208    f=  1.10816D-01    |proj g|=  4.57436D-06
#
# At iterate  209    f=  1.10816D-01    |proj g|=  6.06182D-06
#
# At iterate  210    f=  1.10816D-01    |proj g|=  3.73875D-06
#
# At iterate  211    f=  1.10815D-01    |proj g|=  2.58997D-06
#
# At iterate  212    f=  1.10815D-01    |proj g|=  3.09494D-06
#
# At iterate  213    f=  1.10815D-01    |proj g|=  4.51520D-06
#
# At iterate  214    f=  1.10815D-01    |proj g|=  3.05710D-06
#
# At iterate  215    f=  1.10815D-01    |proj g|=  1.74452D-06
#
# At iterate  216    f=  1.10815D-01    |proj g|=  3.20311D-06
#
# At iterate  217    f=  1.10815D-01    |proj g|=  3.93669D-06
#
# At iterate  218    f=  1.10815D-01    |proj g|=  3.41887D-06
#
# At iterate  219    f=  1.10815D-01    |proj g|=  2.23138D-06
#
# At iterate  220    f=  1.10815D-01    |proj g|=  2.35436D-06
#
# At iterate  221    f=  1.10814D-01    |proj g|=  2.72782D-06
#
# At iterate  222    f=  1.10814D-01    |proj g|=  4.96413D-06
#
# At iterate  223    f=  1.10814D-01    |proj g|=  2.70213D-06
#
# At iterate  224    f=  1.10814D-01    |proj g|=  2.12728D-06
#
# At iterate  225    f=  1.10814D-01    |proj g|=  2.44878D-06
#
# At iterate  226    f=  1.10814D-01    |proj g|=  3.56543D-06
#
# At iterate  227    f=  1.10814D-01    |proj g|=  3.72748D-06
#
# At iterate  228    f=  1.10814D-01    |proj g|=  1.64673D-06
#
# At iterate  229    f=  1.10814D-01    |proj g|=  1.19345D-06
#
# At iterate  230    f=  1.10814D-01    |proj g|=  4.84832D-06
#
# At iterate  231    f=  1.10814D-01    |proj g|=  2.53486D-06
#
# At iterate  232    f=  1.10814D-01    |proj g|=  1.94916D-06
#
# At iterate  233    f=  1.10814D-01    |proj g|=  1.79326D-06
#
# At iterate  234    f=  1.10814D-01    |proj g|=  1.59385D-06
#
# At iterate  235    f=  1.10814D-01    |proj g|=  7.18238D-06
#
# At iterate  236    f=  1.10814D-01    |proj g|=  1.55470D-06
#
# At iterate  237    f=  1.10814D-01    |proj g|=  8.72205D-07
#
# At iterate  238    f=  1.10814D-01    |proj g|=  1.07367D-06
#
# At iterate  239    f=  1.10814D-01    |proj g|=  1.44578D-06
#
# At iterate  240    f=  1.10814D-01    |proj g|=  3.71315D-06
#
# At iterate  241    f=  1.10814D-01    |proj g|=  2.03095D-06
#
# At iterate  242    f=  1.10814D-01    |proj g|=  1.77132D-06
#
# At iterate  243    f=  1.10813D-01    |proj g|=  1.72401D-06
#
# At iterate  244    f=  1.10813D-01    |proj g|=  1.28189D-06
#
# At iterate  245    f=  1.10813D-01    |proj g|=  1.17301D-06
#
# At iterate  246    f=  1.10813D-01    |proj g|=  1.19446D-06
#
# At iterate  247    f=  1.10813D-01    |proj g|=  1.09910D-06
#
# At iterate  248    f=  1.10813D-01    |proj g|=  3.36964D-06
#
# At iterate  249    f=  1.10813D-01    |proj g|=  1.13546D-06
#
# At iterate  250    f=  1.10813D-01    |proj g|=  9.20656D-07
#
# At iterate  251    f=  1.10813D-01    |proj g|=  8.46279D-07
#
# At iterate  252    f=  1.10813D-01    |proj g|=  2.50573D-06
#
# At iterate  253    f=  1.10813D-01    |proj g|=  2.22971D-06
#
# At iterate  254    f=  1.10813D-01    |proj g|=  8.71186D-07
#
# At iterate  255    f=  1.10813D-01    |proj g|=  8.38264D-07
#
# At iterate  256    f=  1.10813D-01    |proj g|=  1.30120D-06
#
# At iterate  257    f=  1.10813D-01    |proj g|=  2.41881D-06
#
# At iterate  258    f=  1.10813D-01    |proj g|=  1.13976D-06
#
# At iterate  259    f=  1.10813D-01    |proj g|=  1.06483D-06
#
# At iterate  260    f=  1.10813D-01    |proj g|=  1.08262D-06
#
# At iterate  261    f=  1.10813D-01    |proj g|=  2.22462D-06
#
# At iterate  262    f=  1.10813D-01    |proj g|=  1.35425D-06
#
# At iterate  263    f=  1.10813D-01    |proj g|=  9.18016D-07
#
# At iterate  264    f=  1.10813D-01    |proj g|=  2.69991D-06
#
# At iterate  265    f=  1.10813D-01    |proj g|=  1.70496D-06
#
# At iterate  266    f=  1.10813D-01    |proj g|=  1.18841D-06
#
# At iterate  267    f=  1.10813D-01    |proj g|=  1.14626D-06
#
# At iterate  268    f=  1.10813D-01    |proj g|=  8.79240D-07
#
# At iterate  269    f=  1.10813D-01    |proj g|=  3.46914D-06
#
# At iterate  270    f=  1.10813D-01    |proj g|=  1.37681D-06
#
# At iterate  271    f=  1.10813D-01    |proj g|=  7.63447D-07
#
# At iterate  272    f=  1.10813D-01    |proj g|=  1.09944D-06
#
# At iterate  273    f=  1.10813D-01    |proj g|=  1.67579D-06
#
# At iterate  274    f=  1.10813D-01    |proj g|=  2.35750D-06
#
# At iterate  275    f=  1.10813D-01    |proj g|=  8.84495D-07
#
# At iterate  276    f=  1.10813D-01    |proj g|=  1.20216D-06
#
# At iterate  277    f=  1.10813D-01    |proj g|=  1.57725D-06
#
#
# At iterate  451    f=  1.10812D-01    |proj g|=  5.52219D-07
#
# At iterate  452    f=  1.10812D-01    |proj g|=  2.52012D-07
#
# At iterate  453    f=  1.10812D-01    |proj g|=  2.75114D-07
#
# At iterate  454    f=  1.10812D-01    |proj g|=  6.15756D-07
#
# At iterate  455    f=  1.10812D-01    |proj g|=  2.71226D-06
#
# At iterate  456    f=  1.10812D-01    |proj g|=  9.83041D-07
#
# At iterate  457    f=  1.10812D-01    |proj g|=  4.51093D-07
#
# At iterate  458    f=  1.10812D-01    |proj g|=  3.73848D-07
#
# At iterate  459    f=  1.10812D-01    |proj g|=  4.31243D-07
#
# At iterate  460    f=  1.10811D-01    |proj g|=  1.58038D-06
#
# At iterate  461    f=  1.10811D-01    |proj g|=  8.96329D-07
#
# At iterate  462    f=  1.10811D-01    |proj g|=  3.87670D-07
#
# At iterate  463    f=  1.10811D-01    |proj g|=  5.69050D-07
#
# At iterate  464    f=  1.10811D-01    |proj g|=  4.33649D-07
#
# At iterate  465    f=  1.10811D-01    |proj g|=  1.58379D-06
#
# At iterate  466    f=  1.10811D-01    |proj g|=  1.87756D-07
#
# At iterate  467    f=  1.10811D-01    |proj g|=  2.65754D-07
#
# At iterate  468    f=  1.10811D-01    |proj g|=  1.17769D-06
#
# At iterate  469    f=  1.10811D-01    |proj g|=  2.81681D-07
#
# At iterate  470    f=  1.10811D-01    |proj g|=  2.49437D-07
#
# At iterate  471    f=  1.10811D-01    |proj g|=  3.47717D-07
#
# At iterate  472    f=  1.10811D-01    |proj g|=  5.19199D-07
#
# At iterate  473    f=  1.10811D-01    |proj g|=  5.07857D-07
#
# At iterate  474    f=  1.10811D-01    |proj g|=  2.76377D-07
#
# At iterate  475    f=  1.10811D-01    |proj g|=  2.28547D-07
#
# At iterate  476    f=  1.10811D-01    |proj g|=  4.25127D-07
#
# At iterate  477    f=  1.10811D-01    |proj g|=  3.89459D-07
#
# At iterate  478    f=  1.10811D-01    |proj g|=  9.14217D-07
#
# At iterate  479    f=  1.10811D-01    |proj g|=  4.48210D-07
#
# At iterate  480    f=  1.10811D-01    |proj g|=  2.44288D-07
#
# At iterate  481    f=  1.10811D-01    |proj g|=  4.65643D-07
#
# At iterate  482    f=  1.10811D-01    |proj g|=  1.01628D-06
#
# At iterate  483    f=  1.10811D-01    |proj g|=  2.58956D-07
#
# At iterate  484    f=  1.10811D-01    |proj g|=  2.84782D-07
#
# At iterate  485    f=  1.10811D-01    |proj g|=  2.73295D-07
#
# At iterate  486    f=  1.10811D-01    |proj g|=  5.02731D-07
#
# At iterate  487    f=  1.10811D-01    |proj g|=  2.97379D-07
#
# At iterate  488    f=  1.10811D-01    |proj g|=  2.02821D-07
#
# At iterate  489    f=  1.10811D-01    |proj g|=  2.00969D-07
#
# At iterate  490    f=  1.10811D-01    |proj g|=  2.84279D-07
#
# At iterate  491    f=  1.10811D-01    |proj g|=  7.05697D-07
#
# At iterate  492    f=  1.10811D-01    |proj g|=  3.50742D-07
#
# At iterate  493    f=  1.10811D-01    |proj g|=  6.19704D-07
#
# At iterate  494    f=  1.10811D-01    |proj g|=  5.51897D-07
#
# At iterate  495    f=  1.10811D-01    |proj g|=  3.76697D-07
#
# At iterate  496    f=  1.10811D-01    |proj g|=  3.45770D-07
#
# At iterate  497    f=  1.10811D-01    |proj g|=  3.18211D-07
#
# At iterate  498    f=  1.10811D-01    |proj g|=  3.87056D-07
#
# At iterate  499    f=  1.10811D-01    |proj g|=  6.78604D-07
#
# At iterate  500    f=  1.10811D-01    |proj g|=  4.85124D-07
#
# At iterate  501    f=  1.10811D-01    |proj g|=  4.94355D-07
#
# At iterate  502    f=  1.10811D-01    |proj g|=  4.75010D-07
#
# At iterate  503    f=  1.10811D-01    |proj g|=  2.19662D-07
#
# At iterate  504    f=  1.10811D-01    |proj g|=  2.58110D-07
#
# At iterate  505    f=  1.10811D-01    |proj g|=  4.43408D-07
#
# At iterate  506    f=  1.10811D-01    |proj g|=  9.42309D-07
#
# At iterate  507    f=  1.10811D-01    |proj g|=  4.17512D-07
#
# At iterate  508    f=  1.10811D-01    |proj g|=  2.40445D-07
#
# At iterate  509    f=  1.10811D-01    |proj g|=  3.37478D-07
#
# At iterate  510    f=  1.10811D-01    |proj g|=  4.92679D-07
#
# At iterate  511    f=  1.10811D-01    |proj g|=  1.70180D-06
#
# At iterate  512    f=  1.10811D-01    |proj g|=  1.08914D-06
#
# At iterate  513    f=  1.10811D-01    |proj g|=  6.68126D-07
#
# At iterate  514    f=  1.10811D-01    |proj g|=  3.60216D-07
#
# At iterate  515    f=  1.10811D-01    |proj g|=  4.80621D-07
#
# At iterate  516    f=  1.10811D-01    |proj g|=  4.96901D-07
#
# At iterate  517    f=  1.10811D-01    |proj g|=  1.73051D-06
#
# At iterate  518    f=  1.10811D-01    |proj g|=  1.18935D-06
#
# At iterate  519    f=  1.10811D-01    |proj g|=  4.66784D-07
#
# At iterate  520    f=  1.10811D-01    |proj g|=  4.11726D-07
#
# At iterate  521    f=  1.10811D-01    |proj g|=  3.93543D-07
#
# At iterate  522    f=  1.10811D-01    |proj g|=  5.86595D-07
#
# At iterate  523    f=  1.10811D-01    |proj g|=  1.89992D-06
#
# At iterate  524    f=  1.10811D-01    |proj g|=  2.29814D-07
#
# At iterate  525    f=  1.10811D-01    |proj g|=  2.21828D-07
#
# At iterate  526    f=  1.10811D-01    |proj g|=  2.14269D-07
#
# At iterate  527    f=  1.10811D-01    |proj g|=  4.00392D-07
#
# At iterate  528    f=  1.10811D-01    |proj g|=  2.32388D-06
#
# At iterate  529    f=  1.10811D-01    |proj g|=  1.04403D-06
#
# At iterate  530    f=  1.10811D-01    |proj g|=  4.02216D-07
#
# At iterate  531    f=  1.10811D-01    |proj g|=  3.04372D-07
#
# At iterate  532    f=  1.10811D-01    |proj g|=  3.35818D-07
#
# At iterate  533    f=  1.10811D-01    |proj g|=  5.27529D-07
#
# At iterate  534    f=  1.10811D-01    |proj g|=  9.83725D-07
#
# At iterate  535    f=  1.10811D-01    |proj g|=  8.11076D-07
#
# At iterate  536    f=  1.10811D-01    |proj g|=  3.16105D-07
#
# At iterate  537    f=  1.10811D-01    |proj g|=  4.78680D-07
#
# At iterate  538    f=  1.10811D-01    |proj g|=  1.03714D-06
#
# At iterate  539    f=  1.10811D-01    |proj g|=  5.49233D-07
#
# At iterate  540    f=  1.10811D-01    |proj g|=  3.11532D-07
#
# At iterate  541    f=  1.10811D-01    |proj g|=  3.85918D-07
#
# At iterate  542    f=  1.10811D-01    |proj g|=  1.06278D-06
#
# At iterate  543    f=  1.10811D-01    |proj g|=  6.91667D-07
#
# At iterate  544    f=  1.10811D-01    |proj g|=  4.02829D-07
#
# At iterate  545    f=  1.10811D-01    |proj g|=  4.11995D-07
#
# At iterate  546    f=  1.10811D-01    |proj g|=  1.48451D-06
#
# At iterate  547    f=  1.10811D-01    |proj g|=  1.05397D-06
#
# At iterate  548    f=  1.10811D-01    |proj g|=  3.61164D-07
#
# At iterate  549    f=  1.10811D-01    |proj g|=  3.83010D-07
#
# At iterate  550    f=  1.10811D-01    |proj g|=  7.25512D-07
#
# At iterate  551    f=  1.10811D-01    |proj g|=  9.11843D-07
#
# At iterate  552    f=  1.10811D-01    |proj g|=  1.31335D-06
#
# At iterate  553    f=  1.10811D-01    |proj g|=  1.22478D-06
#
# At iterate  554    f=  1.10811D-01    |proj g|=  5.22619D-07
#
# At iterate  555    f=  1.10811D-01    |proj g|=  2.28753D-07
#
# At iterate  556    f=  1.10811D-01    |proj g|=  3.24228D-07
#
# At iterate  557    f=  1.10811D-01    |proj g|=  1.13686D-06
#
# At iterate  558    f=  1.10811D-01    |proj g|=  3.14071D-07
#
# At iterate  559    f=  1.10811D-01    |proj g|=  3.11687D-07
#
# At iterate  560    f=  1.10811D-01    |proj g|=  1.13921D-06
#
# At iterate  561    f=  1.10811D-01    |proj g|=  5.30326D-07
#
# At iterate  562    f=  1.10811D-01    |proj g|=  3.86438D-07
#
# At iterate  563    f=  1.10811D-01    |proj g|=  3.41586D-07
#
# At iterate  564    f=  1.10811D-01    |proj g|=  4.58570D-07
#
# At iterate  565    f=  1.10811D-01    |proj g|=  1.24137D-06
#
# At iterate  566    f=  1.10811D-01    |proj g|=  6.78687D-07
#
# At iterate  567    f=  1.10811D-01    |proj g|=  3.21095D-07
#
# At iterate  568    f=  1.10811D-01    |proj g|=  2.12155D-07
#
# At iterate  569    f=  1.10811D-01    |proj g|=  2.08585D-07
#
# At iterate  570    f=  1.10811D-01    |proj g|=  8.82037D-07
#
# At iterate  571    f=  1.10811D-01    |proj g|=  5.80064D-07
#
# At iterate  572    f=  1.10811D-01    |proj g|=  1.77755D-07
#
# At iterate  573    f=  1.10811D-01    |proj g|=  1.79430D-07
#
# At iterate  574    f=  1.10811D-01    |proj g|=  3.07187D-07
#
# At iterate  575    f=  1.10811D-01    |proj g|=  4.84689D-07
#
# At iterate  576    f=  1.10811D-01    |proj g|=  6.98888D-07
#
# At iterate  577    f=  1.10811D-01    |proj g|=  5.19850D-07
#
# At iterate  578    f=  1.10811D-01    |proj g|=  2.64988D-07
#
# At iterate  579    f=  1.10811D-01    |proj g|=  3.76345D-07
#
# At iterate  580    f=  1.10811D-01    |proj g|=  3.81847D-07
#
# At iterate  581    f=  1.10811D-01    |proj g|=  2.99405D-07
#
# At iterate  582    f=  1.10811D-01    |proj g|=  1.79024D-06
#
# At iterate  583    f=  1.10811D-01    |proj g|=  6.07918D-07
#
# At iterate  584    f=  1.10811D-01    |proj g|=  2.56984D-07
#
# At iterate  585    f=  1.10811D-01    |proj g|=  3.83582D-07
#
# At iterate  586    f=  1.10811D-01    |proj g|=  4.08627D-07
#
# At iterate  587    f=  1.10811D-01    |proj g|=  1.01714D-06
#
# At iterate  588    f=  1.10811D-01    |proj g|=  6.01353D-07
#
# At iterate  589    f=  1.10811D-01    |proj g|=  2.97009D-07
#
# At iterate  590    f=  1.10811D-01    |proj g|=  2.47213D-07
#
# At iterate  591    f=  1.10811D-01    |proj g|=  4.25795D-07
#
# At iterate  592    f=  1.10811D-01    |proj g|=  4.18381D-07
#
# At iterate  593    f=  1.10811D-01    |proj g|=  2.01425D-06
#
# At iterate  594    f=  1.10811D-01    |proj g|=  2.92412D-07
#
# At iterate  595    f=  1.10811D-01    |proj g|=  2.52805D-07
#
# At iterate  596    f=  1.10811D-01    |proj g|=  5.96551D-07
#
# At iterate  597    f=  1.10811D-01    |proj g|=  4.57817D-07
#
# At iterate  598    f=  1.10811D-01    |proj g|=  2.36607D-07
#
# At iterate  599    f=  1.10811D-01    |proj g|=  2.48695D-07
#
# At iterate  600    f=  1.10811D-01    |proj g|=  8.55653D-07
#
# At iterate  601    f=  1.10811D-01    |proj g|=  4.31692D-07
#
# At iterate  602    f=  1.10811D-01    |proj g|=  2.51381D-07
#
# At iterate  603    f=  1.10811D-01    |proj g|=  2.04166D-07
#
# At iterate  604    f=  1.10811D-01    |proj g|=  3.29852D-07
#
# At iterate  605    f=  1.10811D-01    |proj g|=  7.43148D-07
#
# At iterate  606    f=  1.10811D-01    |proj g|=  1.39531D-06
#
# At iterate  607    f=  1.10811D-01    |proj g|=  2.36960D-07
#
# At iterate  608    f=  1.10811D-01    |proj g|=  2.10617D-07
#
# At iterate  609    f=  1.10811D-01    |proj g|=  6.30708D-07
#
# At iterate  610    f=  1.10811D-01    |proj g|=  3.83777D-07
#
# At iterate  611    f=  1.10811D-01    |proj g|=  1.68334D-07
#
# At iterate  612    f=  1.10811D-01    |proj g|=  2.16945D-07
#
# At iterate  613    f=  1.10811D-01    |proj g|=  4.69813D-07
#
# At iterate  614    f=  1.10811D-01    |proj g|=  6.77059D-07
#
# At iterate  615    f=  1.10811D-01    |proj g|=  2.59157D-07
#
# At iterate  616    f=  1.10811D-01    |proj g|=  2.05704D-07
#
# At iterate  617    f=  1.10811D-01    |proj g|=  3.42806D-07
#
# At iterate  618    f=  1.10811D-01    |proj g|=  3.46520D-07
#
# At iterate  619    f=  1.10811D-01    |proj g|=  1.15273D-06
#
# At iterate  620    f=  1.10811D-01    |proj g|=  2.34814D-07
#
# At iterate  621    f=  1.10811D-01    |proj g|=  1.75400D-07
#
# At iterate  622    f=  1.10811D-01    |proj g|=  5.97987D-07
#
# At iterate  623    f=  1.10811D-01    |proj g|=  1.23407D-06
#
# At iterate  624    f=  1.10811D-01    |proj g|=  2.78306D-07
#
# At iterate  625    f=  1.10811D-01    |proj g|=  1.66973D-07
#
# At iterate  626    f=  1.10811D-01    |proj g|=  3.61748D-07
#
# At iterate  627    f=  1.10811D-01    |proj g|=  6.37121D-07
#
# At iterate  628    f=  1.10811D-01    |proj g|=  3.53776D-07
#
# At iterate  629    f=  1.10811D-01    |proj g|=  1.71806D-07
#
# At iterate  630    f=  1.10811D-01    |proj g|=  2.47491D-07
#
# At iterate  631    f=  1.10811D-01    |proj g|=  3.62914D-07
#
# At iterate  632    f=  1.10811D-01    |proj g|=  5.80344D-07
#
# At iterate  633    f=  1.10811D-01    |proj g|=  8.43697D-07
#
# At iterate  634    f=  1.10811D-01    |proj g|=  1.74127D-07
#
# At iterate  635    f=  1.10811D-01    |proj g|=  1.97822D-07
#
# At iterate  636    f=  1.10811D-01    |proj g|=  8.76733D-07
#
# At iterate  637    f=  1.10811D-01    |proj g|=  5.24015D-07
#
# At iterate  638    f=  1.10811D-01    |proj g|=  3.70164D-07
#
# At iterate  639    f=  1.10811D-01    |proj g|=  3.03919D-07
#
# At iterate  640    f=  1.10811D-01    |proj g|=  3.46678D-07
#
# At iterate  641    f=  1.10811D-01    |proj g|=  3.18709D-07
#
# At iterate  642    f=  1.10811D-01    |proj g|=  1.46398D-07
#
# At iterate  643    f=  1.10811D-01    |proj g|=  1.23714D-07
#
# At iterate  644    f=  1.10811D-01    |proj g|=  1.87954D-07
#
# At iterate  645    f=  1.10811D-01    |proj g|=  2.05854D-07
#
# At iterate  646    f=  1.10811D-01    |proj g|=  7.21013D-07
#
# At iterate  647    f=  1.10811D-01    |proj g|=  1.53590D-07
#
# At iterate  648    f=  1.10811D-01    |proj g|=  2.77487D-07
#
# At iterate  649    f=  1.10811D-01    |proj g|=  5.37089D-07
#
# At iterate  650    f=  1.10811D-01    |proj g|=  1.73160D-07
#
# At iterate  651    f=  1.10811D-01    |proj g|=  1.52490D-07
#
# At iterate  652    f=  1.10811D-01    |proj g|=  2.47660D-07
#
# At iterate  653    f=  1.10811D-01    |proj g|=  2.81649D-07
#
# At iterate  654    f=  1.10811D-01    |proj g|=  3.16950D-07
#
# At iterate  655    f=  1.10811D-01    |proj g|=  1.42744D-07
#
# At iterate  656    f=  1.10811D-01    |proj g|=  1.53724D-07
#
# At iterate  657    f=  1.10811D-01    |proj g|=  2.05188D-07
#
# At iterate  658    f=  1.10811D-01    |proj g|=  1.58359D-07
#
# At iterate  659    f=  1.10811D-01    |proj g|=  5.47537D-07
#
# At iterate  660    f=  1.10811D-01    |proj g|=  4.12907D-07
#
# At iterate  661    f=  1.10811D-01    |proj g|=  2.60904D-07
#
# At iterate  662    f=  1.10811D-01    |proj g|=  2.32059D-07
#
# At iterate  663    f=  1.10811D-01    |proj g|=  1.97485D-07
#
# At iterate  664    f=  1.10811D-01    |proj g|=  1.43217D-07
#
# At iterate  665    f=  1.10811D-01    |proj g|=  3.11985D-07
#
# At iterate  666    f=  1.10811D-01    |proj g|=  3.34919D-07
#
# At iterate  667    f=  1.10811D-01    |proj g|=  4.19846D-07
#
# At iterate  668    f=  1.10811D-01    |proj g|=  1.70451D-07
#
# At iterate  669    f=  1.10811D-01    |proj g|=  2.75021D-07
#
# At iterate  670    f=  1.10811D-01    |proj g|=  1.39540D-07
#
# At iterate  671    f=  1.10811D-01    |proj g|=  1.39842D-07
#
# At iterate  672    f=  1.10811D-01    |proj g|=  1.45466D-07
#
# At iterate  673    f=  1.10811D-01    |proj g|=  6.48374D-07
#
# At iterate  674    f=  1.10811D-01    |proj g|=  1.82741D-07
#
# At iterate  675    f=  1.10811D-01    |proj g|=  1.43963D-07
#
# At iterate  676    f=  1.10811D-01    |proj g|=  2.44895D-07
#
# At iterate  677    f=  1.10811D-01    |proj g|=  4.00854D-07
#
# At iterate  678    f=  1.10811D-01    |proj g|=  1.79572D-07
#
# At iterate  679    f=  1.10811D-01    |proj g|=  3.75085D-07
#
# At iterate  680    f=  1.10811D-01    |proj g|=  5.77486D-07
#
# At iterate  681    f=  1.10811D-01    |proj g|=  2.38827D-07
#
# At iterate  682    f=  1.10811D-01    |proj g|=  2.06495D-07
#
# At iterate  683    f=  1.10811D-01    |proj g|=  2.41348D-07
#
# At iterate  684    f=  1.10811D-01    |proj g|=  2.77794D-07
#
# At iterate  685    f=  1.10811D-01    |proj g|=  1.10376D-06
#
# At iterate  686    f=  1.10811D-01    |proj g|=  2.77669D-07
#
# At iterate  687    f=  1.10811D-01    |proj g|=  2.07871D-07
#
# At iterate  688    f=  1.10811D-01    |proj g|=  1.42112D-07
#
# At iterate  689    f=  1.10811D-01    |proj g|=  1.69057D-07
#
# At iterate  690    f=  1.10811D-01    |proj g|=  2.77038D-07
#
# At iterate  691    f=  1.10811D-01    |proj g|=  4.81204D-07
#
# At iterate  692    f=  1.10811D-01    |proj g|=  4.80053D-07
#
# At iterate  693    f=  1.10811D-01    |proj g|=  2.36014D-07
#
# At iterate  694    f=  1.10811D-01    |proj g|=  2.35859D-07
#
# At iterate  695    f=  1.10811D-01    |proj g|=  2.19576D-07
#
# At iterate  696    f=  1.10811D-01    |proj g|=  3.69078D-07
#
# At iterate  697    f=  1.10811D-01    |proj g|=  6.76687D-07
#
# At iterate  698    f=  1.10811D-01    |proj g|=  2.96634D-07
#
# At iterate  699    f=  1.10811D-01    |proj g|=  2.63576D-07
#
# At iterate  700    f=  1.10811D-01    |proj g|=  1.79120D-07
#
# At iterate  701    f=  1.10811D-01    |proj g|=  1.86469D-07
#
# At iterate  702    f=  1.10811D-01    |proj g|=  4.01457D-07
#
# At iterate  703    f=  1.10811D-01    |proj g|=  3.96474D-07
#
# At iterate  704    f=  1.10811D-01    |proj g|=  1.56990D-07
#
# At iterate  705    f=  1.10811D-01    |proj g|=  2.08851D-07
#
# At iterate  706    f=  1.10811D-01    |proj g|=  1.66459D-07
#
# At iterate  707    f=  1.10811D-01    |proj g|=  1.91331D-07
#
# At iterate  708    f=  1.10811D-01    |proj g|=  2.19351D-07
#
# At iterate  709    f=  1.10811D-01    |proj g|=  5.03518D-07
#
# At iterate  710    f=  1.10811D-01    |proj g|=  1.57429D-07
#
# At iterate  711    f=  1.10811D-01    |proj g|=  1.76003D-07
#
# At iterate  712    f=  1.10811D-01    |proj g|=  2.02544D-07
#
# At iterate  713    f=  1.10811D-01    |proj g|=  3.92973D-07
#
# At iterate  714    f=  1.10811D-01    |proj g|=  1.68394D-07
#
# At iterate  715    f=  1.10811D-01    |proj g|=  2.37225D-07
#
# At iterate  716    f=  1.10811D-01    |proj g|=  2.34718D-07
#
# At iterate  717    f=  1.10811D-01    |proj g|=  2.30322D-07
#
# At iterate  718    f=  1.10811D-01    |proj g|=  1.96539D-07
#
# At iterate  719    f=  1.10811D-01    |proj g|=  6.75983D-07
#
# At iterate  720    f=  1.10811D-01    |proj g|=  1.73275D-07
#
# At iterate  721    f=  1.10811D-01    |proj g|=  3.15647D-07
#
# At iterate  722    f=  1.10811D-01    |proj g|=  1.72913D-07
#
# At iterate  723    f=  1.10811D-01    |proj g|=  1.53717D-07
#
# At iterate  724    f=  1.10811D-01    |proj g|=  1.61266D-07
#
# At iterate  725    f=  1.10811D-01    |proj g|=  1.28214D-06
#
# At iterate  726    f=  1.10811D-01    |proj g|=  3.52980D-07
#
# At iterate  727    f=  1.10811D-01    |proj g|=  1.20387D-07
#
# At iterate  728    f=  1.10811D-01    |proj g|=  4.33331D-07
#
# At iterate  729    f=  1.10811D-01    |proj g|=  3.16097D-07
#
# At iterate  730    f=  1.10811D-01    |proj g|=  1.92565D-07
#
# At iterate  731    f=  1.10811D-01    |proj g|=  1.91526D-07
#
# At iterate  732    f=  1.10811D-01    |proj g|=  1.86887D-07
#
# At iterate  733    f=  1.10811D-01    |proj g|=  4.97081D-07
#
# At iterate  734    f=  1.10811D-01    |proj g|=  3.00781D-07
#
# At iterate  735    f=  1.10811D-01    |proj g|=  1.35025D-07
#
# At iterate  736    f=  1.10811D-01    |proj g|=  1.29698D-07
#
# At iterate  737    f=  1.10811D-01    |proj g|=  2.00537D-07
#
# At iterate  738    f=  1.10811D-01    |proj g|=  7.47372D-07
#
# At iterate  739    f=  1.10811D-01    |proj g|=  3.79175D-07
#
# At iterate  740    f=  1.10811D-01    |proj g|=  2.49428D-07
#
# At iterate  741    f=  1.10811D-01    |proj g|=  6.11788D-07
#
# At iterate  742    f=  1.10811D-01    |proj g|=  4.14525D-07
#
# At iterate  743    f=  1.10811D-01    |proj g|=  2.32345D-07
#
# At iterate  744    f=  1.10811D-01    |proj g|=  1.58796D-07
#
# At iterate  745    f=  1.10811D-01    |proj g|=  1.35878D-07
#
# At iterate  746    f=  1.10811D-01    |proj g|=  6.83342D-07
#
# At iterate  747    f=  1.10811D-01    |proj g|=  1.82381D-07
#
# At iterate  748    f=  1.10811D-01    |proj g|=  1.65202D-07
#
# At iterate  749    f=  1.10811D-01    |proj g|=  2.12167D-07
#
# At iterate  750    f=  1.10811D-01    |proj g|=  2.36667D-07
#
# At iterate  751    f=  1.10811D-01    |proj g|=  5.24278D-07
#
# At iterate  752    f=  1.10811D-01    |proj g|=  2.93512D-07
#
# At iterate  753    f=  1.10811D-01    |proj g|=  5.72263D-07
#
# At iterate  754    f=  1.10811D-01    |proj g|=  1.85558D-07
#
# At iterate  755    f=  1.10811D-01    |proj g|=  1.52631D-07
#
# At iterate  756    f=  1.10811D-01    |proj g|=  1.73910D-07
#
# At iterate  757    f=  1.10811D-01    |proj g|=  2.19186D-07
#
# At iterate  758    f=  1.10811D-01    |proj g|=  6.78463D-07
#
# At iterate  759    f=  1.10811D-01    |proj g|=  6.88417D-07
#
# At iterate  760    f=  1.10811D-01    |proj g|=  1.50314D-07
#
# At iterate  761    f=  1.10811D-01    |proj g|=  1.21326D-07
#
# At iterate  762    f=  1.10811D-01    |proj g|=  1.74647D-07
#
# At iterate  763    f=  1.10811D-01    |proj g|=  1.96342D-07
#
# At iterate  764    f=  1.10811D-01    |proj g|=  4.66017D-07
#
# At iterate  765    f=  1.10811D-01    |proj g|=  4.04679D-07
#
# At iterate  766    f=  1.10811D-01    |proj g|=  1.25530D-07
#
# At iterate  767    f=  1.10811D-01    |proj g|=  1.41025D-07
#
# At iterate  768    f=  1.10811D-01    |proj g|=  3.18010D-07
#
# At iterate  769    f=  1.10811D-01    |proj g|=  2.03335D-07
#
# At iterate  770    f=  1.10811D-01    |proj g|=  3.25787D-07
# ...
#
# At iterate 9940    f=  1.10811D-01    |proj g|=  7.85552D-09
#
# At iterate 9941    f=  1.10811D-01    |proj g|=  2.89597D-09
#
# At iterate 9942    f=  1.10811D-01    |proj g|=  3.87055D-09
#
# At iterate 9943    f=  1.10811D-01    |proj g|=  3.14723D-09
#
# At iterate 9944    f=  1.10811D-01    |proj g|=  1.08542D-08
#
# At iterate 9945    f=  1.10811D-01    |proj g|=  1.60134D-08
#
# At iterate 9946    f=  1.10811D-01    |proj g|=  2.46614D-09
#
# At iterate 9947    f=  1.10811D-01    |proj g|=  1.93129D-09
#
# At iterate 9948    f=  1.10811D-01    |proj g|=  4.46089D-09
#
# At iterate 9949    f=  1.10811D-01    |proj g|=  5.98246D-09
#
# At iterate 9950    f=  1.10811D-01    |proj g|=  3.66167D-09
#
# At iterate 9951    f=  1.10811D-01    |proj g|=  1.80634D-09
#
# At iterate 9952    f=  1.10811D-01    |proj g|=  1.97240D-09
#
# At iterate 9953    f=  1.10811D-01    |proj g|=  1.79376D-08
#
# At iterate 9954    f=  1.10811D-01    |proj g|=  7.03511D-09
#
# At iterate 9955    f=  1.10811D-01    |proj g|=  2.71289D-09
#
# At iterate 9956    f=  1.10811D-01    |proj g|=  2.98617D-09
#
# At iterate 9957    f=  1.10811D-01    |proj g|=  4.81056D-09
#
# At iterate 9958    f=  1.10811D-01    |proj g|=  2.10686D-08
#
# At iterate 9959    f=  1.10811D-01    |proj g|=  3.20765D-09
#
# At iterate 9960    f=  1.10811D-01    |proj g|=  1.39796D-09
#
# At iterate 9961    f=  1.10811D-01    |proj g|=  4.15254D-09
#
# At iterate 9962    f=  1.10811D-01    |proj g|=  2.94610D-09
#
# At iterate 9963    f=  1.10811D-01    |proj g|=  1.93360D-09
#
# At iterate 9964    f=  1.10811D-01    |proj g|=  2.68131D-09
#
# At iterate 9965    f=  1.10811D-01    |proj g|=  7.36081D-09
#
# At iterate 9966    f=  1.10811D-01    |proj g|=  4.78046D-09
#
# At iterate 9967    f=  1.10811D-01    |proj g|=  2.15683D-09
#
# At iterate 9968    f=  1.10811D-01    |proj g|=  2.09275D-09
#
# At iterate 9969    f=  1.10811D-01    |proj g|=  3.31580D-09
#
# At iterate 9970    f=  1.10811D-01    |proj g|=  4.80455D-09
#
# At iterate 9971    f=  1.10811D-01    |proj g|=  1.27369D-08
#
# At iterate 9972    f=  1.10811D-01    |proj g|=  1.17988D-08
#
# At iterate 9973    f=  1.10811D-01    |proj g|=  5.06916D-09
#
# At iterate 9974    f=  1.10811D-01    |proj g|=  2.04116D-09
#
# At iterate 9975    f=  1.10811D-01    |proj g|=  2.13252D-09
#
# At iterate 9976    f=  1.10811D-01    |proj g|=  2.72710D-09
#
# At iterate 9977    f=  1.10811D-01    |proj g|=  3.44549D-09
#
# At iterate 9978    f=  1.10811D-01    |proj g|=  1.10060D-08
#
# At iterate 9979    f=  1.10811D-01    |proj g|=  5.54702D-09
#
# At iterate 9980    f=  1.10811D-01    |proj g|=  2.56101D-09
#
# At iterate 9981    f=  1.10811D-01    |proj g|=  3.01301D-09
#
# At iterate 9982    f=  1.10811D-01    |proj g|=  4.07489D-09
#
# At iterate 9983    f=  1.10811D-01    |proj g|=  4.94935D-09
#
# At iterate 9984    f=  1.10811D-01    |proj g|=  1.47152D-08
#
# At iterate 9985    f=  1.10811D-01    |proj g|=  7.88530D-09
#
# At iterate 9986    f=  1.10811D-01    |proj g|=  2.62161D-09
#
# At iterate 9987    f=  1.10811D-01    |proj g|=  3.67425D-09
#
# At iterate 9988    f=  1.10811D-01    |proj g|=  5.30412D-09
#
# At iterate 9989    f=  1.10811D-01    |proj g|=  8.14921D-09
#
# At iterate 9990    f=  1.10811D-01    |proj g|=  7.84127D-09
#
# At iterate 9991    f=  1.10811D-01    |proj g|=  4.07116D-09
#
# At iterate 9992    f=  1.10811D-01    |proj g|=  5.08502D-09
#
# At iterate 9993    f=  1.10811D-01    |proj g|=  5.66503D-09
#
# At iterate 9994    f=  1.10811D-01    |proj g|=  6.91886D-09
#
# At iterate 9995    f=  1.10811D-01    |proj g|=  1.94319D-08
#
# At iterate 9996    f=  1.10811D-01    |proj g|=  2.81574D-09
#
# At iterate 9997    f=  1.10811D-01    |proj g|=  2.89994D-09
#
# At iterate 9998    f=  1.10811D-01    |proj g|=  4.84949D-09
#
# At iterate 9999    f=  1.10811D-01    |proj g|=  3.03631D-09
# False
# 0.11081101336138435
#
# At iterate10000    f=  1.10811D-01    |proj g|=  1.77508D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#   300  10000  10886      1     0     0   1.775D-08   1.108D-01
#   F =  0.11081101336138435
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#       fun: 0.11081101336138435
#  hess_inv: <300x300 LbfgsInvHessProduct with dtype=float64>
#       jac: array([
#         6.86974042e-01,  6.86974042e-01,  6.86974042e-01,  6.86974042e-01,
#         7.23582001e-01,  2.49845972e+00,  1.80693452e+01,  3.37003663e+00,
#        -1.34301717e+00, -1.72770054e+00, -8.62526456e-01,  5.50209066e+00,
#        -2.44126038e+00,  1.12084244e-01,  4.72136534e-02, -2.14438398e+00])
# CPU times: user 2min 20s, sys: 3.33 s, total: 2min 23s
# Wall time: 2min 52s

# %%
save_solution(dataset, l2, l1, np.array(res_solver.x), res_solver.fun)

# %% [markdown]
# ### Noise distribution

# %%
x_star = read_solution(dataset, 0, 0)[0]
f_star = read_solution(dataset, 0, 0)[1]

# %%
norm(logreg_grad(x_star, [denseA, y, 0, False]))
# Out:
# 3.9526218763975255e-08

# %%
# %%time
x = deepcopy(x_star)
grad_deviations = np.array([])
full_grad = logreg_grad(x, [denseA,y,0,False])
for i in range(m):
    grad_deviations = np.append(grad_deviations, np.linalg.norm(logreg_grad(x, [denseA[[i]],y[[i]],0,False]) - full_grad))
# Out:
# CPU times: user 14.2 s, sys: 195 ms, total: 14.4 s
# Wall time: 15.1 s

# %%
np.sort(grad_deviations)
# Out:
# array([3.71533049e-08, 3.84556732e-08, 3.86506404e-08, ...,
#        7.54983442e+00, 7.99999192e+00, 8.12403839e+00])

# %%
mu = np.mean(grad_deviations)
sigma = np.sqrt(np.mean((grad_deviations - mu)**2))
print(mu)
print(sigma)
# Out:
# 0.05127692060050925
# 0.29075174828256845

# %%
plt.figure(figsize=(12,8))
plt.xticks(fontsize=25)
plt.yticks(fontsize=30)
t, bins, patches = plt.hist(np.sort(grad_deviations), bins=500, density=1, log=True)
temp2 = np.linspace(0, 8.2, 1000)
plt.semilogy(temp2, norm_d.pdf(temp2, mu, sigma), linewidth=2, color='red', marker='d',
            markersize = 15, 
            markevery=range(0, 1000, 100))
plt.title('w8a, real samples', fontsize=35)
plt.xlabel("Noise norm", fontsize=40)
plt.ylabel("Density", fontsize=40)
plt.savefig("plot/w8a_real.pdf", bbox_inches='tight')

# %%
plt.figure(figsize=(12,8))
plt.xticks(fontsize=25)
plt.yticks(fontsize=30)
sample = norm_d.rvs(loc=mu, scale=sigma, size=m)
sample = sample[sample > 0]
t, bins, patches = plt.hist(sample, bins=500, density=(1 - norm_d.cdf(0,loc=mu,scale=sigma)), log=True)
# t, bins, patches = plt.hist(np.where(sample>0, sample, 0), bins=50, density=1, log=True)
temp2 = np.linspace(0, 8.2, 1000)
# plt.plot(temp2, norm_d.pdf(temp2, mu, sigma))
plt.semilogy(temp2, norm_d.pdf(temp2, mu, sigma), linewidth=2, color='red', marker='d',
            markersize = 15, 
            markevery=range(0, 1000, 100))
plt.title('w8a, synthetic Gaussian samples', fontsize=35)
plt.xlabel("Noise norm", fontsize=40)
plt.ylabel("Density", fontsize=40)
plt.savefig("plot/w8a_synthetic.pdf", bbox_inches='tight')

# %% [markdown]
# ### Tests

# %%
shift_param = 2.0
filename=dataset+"_x_star_shifted_by_all_ones_shift_"+str(shift_param)
l2 = 0
l1 = 0
batch_size = 1000
gamma = 1.0/(L+l2)
x_star = read_solution(dataset, l2, l1)[0]
f_star = read_solution(dataset, l2, l1)[1]
x_init = x_star + shift_param*np.ones(n)
lambd = 2*np.sqrt(2)*(L+l2)*norm(x_star-x_init)
S = 500
save_info_period = 100
beta = 0.001
N = int(S*m/batch_size)
a = ((np.log(4*N/beta)) ** 2)
print("a = ", a)

B = norm(x_star-x_init) / (np.log(4*N/beta))
print("B = ", B)

sparse_full = True
sparse_stoch = True
# Out:
# a =  339.1353546460121
# B =  1.8810662417151167

# %%
print("gamma = ", gamma)
# Out:
# gamma =  1.5124031017732276

# %%
print("Functional suboptimality: ", logreg_loss(x_init, [denseA,y,l2,False,0])-f_star)
# Out:
# Functional suboptimality:  9.49610331220684

# %%
print(lambd)
# Out:
# 64.78404441015115

# %% [markdown]
# ### SSTM tuning

# %%
# %%time
res = sstm(filename=filename, x_init=x_init, A=A, y=y, a=1.0,
             L=L+l2, l2=l2, 
             sparse_full=sparse_full, sparse_stoch=sparse_stoch, 
             S=S, max_t=np.inf,
             batch_size=batch_size, indices=None, save_info_period=save_info_period, 
             x_star=x_star, f_star=f_star)
# Out:
# CPU times: user 45.9 s, sys: 230 ms, total: 46.2 s
# Wall time: 49.1 s

# %%
# %%time

res = clipped_sstm(filename=filename, x_init=x_init, A=A, y=y, a=1.0,
             B=B*0.1, L=L+l2, l2=l2, 
             sparse_full=sparse_full, sparse_stoch=sparse_stoch, 
             S=S, max_t=np.inf,
             batch_size=batch_size, indices=None, save_info_period=save_info_period, 
             x_star=x_star, f_star=f_star)
# Out:
# CPU times: user 47.5 s, sys: 186 ms, total: 47.7 s
# Wall time: 48.8 s

# %% [markdown]
# ### SGD and clipped-SGD

# %%
# %%time
lambd_schedule = [lambd, 50, 0.9]
res = clipped_sgd_const_stepsize_decr_clip(filename=filename, x_init=x_init, A=A, y=y, gamma=gamma,
     lambd_schedule=lambd_schedule, l2=l2, 
     sparse_full=sparse_full, sparse_stoch=sparse_stoch, 
     l1=l1, S=S, max_t=np.inf,
     batch_size=batch_size, indices=None, save_info_period=save_info_period, 
     x_star=x_star, f_star=f_star)
# Out:
# CPU times: user 48.5 s, sys: 421 ms, total: 49 s
# Wall time: 53.4 s

# %%
# %%time
res = clipped_sgd_const_stepsize(filename=filename, x_init=x_init, A=A, y=y, gamma=gamma,
     lambd=lambd*0.02, l2=l2, 
     sparse_full=sparse_full, sparse_stoch=sparse_stoch, 
     l1=l1, S=S, max_t=np.inf,
     batch_size=batch_size, indices=None, save_info_period=save_info_period, 
     x_star=x_star, f_star=f_star)
# Out:
# CPU times: user 49.1 s, sys: 564 ms, total: 49.6 s
# Wall time: 1min 4s

# %%
# %%time
res = sgd_const_stepsize(filename=filename, x_init=x_init, A=A, y=y, gamma=gamma,
                            l2=l2, 
                            sparse_full=sparse_full, sparse_stoch=sparse_stoch, 
                            l1=l1, S=S, max_t=np.inf,
                            batch_size=batch_size, indices=None, save_info_period=save_info_period, 
                            x_star=x_star, f_star=f_star)
# Out:
# CPU times: user 45.3 s, sys: 245 ms, total: 45.6 s
# Wall time: 47.9 s

# %%
methods = [
         ['SGD_const_stepsize', [gamma, l2, l1, S, batch_size], 
           'SGD', None],
         ['clipped-SGD_const_stepsize', [gamma, lambd*0.02, l2, l1, S, batch_size], 
           'clipped-SGD', None],
         ['clipped-SGD_const_stepsize_decr_clip', [gamma, 
                                                   lambd_schedule,
                                                   l2, l1, S, batch_size], 
           'd-clipped-SGD', None],
           ['clipped-SSTM', [1.0, B*0.1, L+l2, l2, S, batch_size], 
           'clipped-SSTM', None],
         ['SSTM', [1.0, L+l2, l2, S, batch_size], 
           'SSTM', None],
]
mode_y = 'func_vals'
mode_x = 'data_passes'
figsize = (12, 8)
title_size = 30
linewidth = 2
markersize = 15
legend_size = 25
xlabel_size = 30
ylabel_size = 40
xticks_size = 30
yticks_size = 30
sizes = [title_size, linewidth, markersize, legend_size, xlabel_size, ylabel_size, xticks_size, yticks_size]
title = dataset
bbox_to_anchor = (1,1)
legend_loc="upper right"


save_fig = [True, filename+"_test_test.pdf"]

args_for_plots = [filename, mode_y, mode_x, figsize, sizes, title, methods, bbox_to_anchor, legend_loc, save_fig]
make_plots(args_for_plots)

# %%
res = read_results_from_file(filename, 'SGD_const_stepsize', [gamma, l2, l1, S, batch_size])

# %%
# %%time
x = deepcopy(res['last_iter'])
grad_deviations = np.array([])
full_grad = logreg_grad(x, [denseA,y,0,False])
for i in range(m):
    grad_deviations = np.append(grad_deviations, np.linalg.norm(logreg_grad(x, [denseA[[i]],y[[i]],0,False]) - full_grad))
# Out:
# CPU times: user 11.7 s, sys: 231 ms, total: 12 s
# Wall time: 11.9 s

# %%
print(norm(full_grad))
# Out:
# 0.00023072277332113618

# %%
mu = np.mean(grad_deviations)
sigma = np.sqrt(np.mean((grad_deviations - mu)**2))
print(mu)
print(sigma)
# Out:
# 0.04979978274416479
# 0.29013241151216873

# %%
plt.figure(figsize=(12,8))
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
t, bins, patches = plt.hist(np.sort(grad_deviations), bins=1000, density=1, log=True)
temp2 = np.linspace(0, 8, 1000)
plt.semilogy(temp2, norm_d.pdf(temp2, mu, sigma), linewidth=2, color='red', marker='d',
            markersize = 15, 
            markevery=range(0, 1000, 100))
plt.title('w8a, real samples', fontsize=35)
plt.xlabel("Noise norm", fontsize=40)
plt.ylabel("Density", fontsize=40)
plt.savefig("plot/w8a_sgd_last_point_big_step.pdf", bbox_inches='tight')

# %%
plt.figure(figsize=(12,8))
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
sample = norm_d.rvs(loc=mu, scale=sigma, size=m)
sample = sample[sample > 0]
t, bins, patches = plt.hist(sample, bins=1000, density=(1 - norm_d.cdf(0,loc=mu,scale=sigma)), log=True)
temp2 = np.linspace(0, 8, 1000)
plt.semilogy(temp2, norm_d.pdf(temp2, mu, sigma), linewidth=2, color='red', marker='d',
            markersize = 15, 
            markevery=range(0, 1000, 100))
plt.title('w8a, synthetic Gaussian samples', fontsize=35)
plt.xlabel("Noise norm", fontsize=40)
plt.ylabel("Density", fontsize=40)
plt.savefig("plot/w8a_synthetic_sgd_last_iter_big_step.pdf", bbox_inches='tight')
